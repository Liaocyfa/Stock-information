# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.38-py2.py3-none-any.whl (72 kB)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: html5lib>=1.1 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (1.1)
# Collecting requests>=2.31
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (1.20.3)
# Collecting pytz>=2022.5
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (1.3.4)
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Collecting lxml>=4.9.1
#   Downloading lxml-5.2.1-cp39-cp39-win_amd64.whl (3.8 MB)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Collecting peewee>=3.16.2
#   Downloading peewee-3.17.3.tar.gz (3.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.4.2-cp39-cp39-win_amd64.whl (36 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.2.1)
# Requirement already satisfied: six>=1.9 in c:\users\user\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2021.10.8)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (PEP 517): started
#   Building wheel for peewee (PEP 517): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.3-py3-none-any.whl size=138453 sha256=86473e5a4e0cc243dd6cc101495675d10793dce2ce698dd1f1557f8a82d14c8d
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\a7\64\49\81f05b55b5fcafe2ea6316aac808b15228715abc3d2632a240
# Successfully built peewee
# Installing collected packages: pytz, requests, peewee, multitasking, lxml, frozendict, beautifulsoup4, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.3
#     Uninstalling pytz-2021.3:
#       Successfully uninstalled pytz-2021.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.6.3
#     Uninstalling lxml-4.6.3:
#       Successfully uninstalled lxml-4.6.3
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.10.0
#     Uninstalling beautifulsoup4-4.10.0:
#       Successfully uninstalled beautifulsoup4-4.10.0
# Successfully installed beautifulsoup4-4.12.3 frozendict-2.4.2 lxml-5.2.1 multitasking-0.0.11 peewee-3.17.3 pytz-2024.1 requests-2.31.0 yfinance-0.2.38
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
start_date='1999-01-01'
end_date='2023-12-31'
#長榮,和碩,聯電
tickers_list=['2603.TW','4938.TW','2303.TW']
data=pd.DataFrame(columns=tickers_list)
for ticker in tickers_list:
    data[ticker]=yf.download(ticker,start_date,end_date)['Adj Close']
data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#              2603.TW  4938.TW    2303.TW
# Date
# 2000-01-04  8.245480      NaN  21.108095
# 2000-01-05  8.153862      NaN  21.019032
# 2000-01-06  8.367633      NaN  20.573713
# 2000-01-07  8.947874      NaN  19.950268
# 2000-01-10  8.856254      NaN  20.484648

# %%
data.plot(figsize=(10,7))
plt.legend()
plt.ylabel('Price',fontsize=14)
plt.xlabel('Year',fontsize=14)
plt.grid(which='major',color='k',linestyle='-.',linewidth=0.5)
plt.title('Portfolio',fontsize=14)
plt.show()
